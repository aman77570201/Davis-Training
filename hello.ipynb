# %% [markdown]
# <a href="https://colab.research.google.com/github/aman77570201/Davis-Training/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome")
print("first time")
# Out:
# welcome
